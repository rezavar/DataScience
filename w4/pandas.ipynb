# %% [markdown]
# لیست پکیج های موجود در سیستم

# %%
pip list
# Out:
# Package                   Version
# ------------------------- ------------
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.13.0
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.1.0
# certifi                   2023.7.22
# cffi                      1.16.0
# charset-normalizer        3.3.0
# colorama                  0.4.6
# comm                      0.1.4
# contourpy                 1.1.1
# cycler                    0.12.1
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.0.0
# fastjsonschema            2.18.1
# fonttools                 4.43.1
# fqdn                      1.5.1
# idna                      3.4
# ...

# %% [markdown]
# وارد کردن پکیج سیستم
# گرفتن مسیر جاری
# تبدیل یک مسیر ابسلوت به مسیر کامل برای باز کردن فایل

# %%
import os
print(os.getcwdb())

Salaries_gile_path = os.path.abspath("..\\data_set\\Salaries.csv")
print (Salaries_gile_path)
# Out:
# b'd:\\app\\python\\DataScience\\w4'
# d:\app\python\DataScience\data_set\Salaries.csv

# %% [markdown]
# وارد کردن پیکج پانداس
# خواندن فایل اکسل
# نمایش دو خط بالای فایل

# %%
import pandas as pd
sal = pd.read_csv(Salaries_gile_path)
sal.head(2)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %% [markdown]
# نمایش دو خط پایین فایل

# %%
sal.tail(2)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %% [markdown]
# نمایش اطلاعات فایل

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# لیست ستون های فایل اکسل

# %%
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# تعداد سطر و ستون فایل

# %%
sal.shape
# Out:
# (148654, 13)

# %% [markdown]
# نمایش یک سری اطلاات آماری
# هر ستون چند تا عضو دارد
# متوسط مقدارش چی هست
# استاندارد اون ستون چی هست
# کمترین مقدار
# بیشترین مقدار

# %%
sal.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %% [markdown]
# نمایش ستون EmployeeName
# نمایش ردیف دوم این ستون

# %%
print(sal['EmployeeName'])
print("\n")
print(sal['EmployeeName'][2])
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object
#
#
# ALBERT PARDINI

# %%
print(type(sal['EmployeeName']))
lst = list(sal['EmployeeName'])
lst
# Out:
# <class 'pandas.core.series.Series'>
# ['NATHANIEL FORD',
#  'GARY JIMENEZ',
#  'ALBERT PARDINI',
#  'CHRISTOPHER CHONG',
#  'PATRICK GARDNER',
#  'DAVID SULLIVAN',
#  'ALSON LEE',
#  'DAVID KUSHNER',
#  'MICHAEL MORRIS',
#  'JOANNE HAYES-WHITE',
#  'ARTHUR KENNEY',
#  'PATRICIA JACKSON',
#  'EDWARD HARRINGTON',
#  'JOHN MARTIN',
#  'DAVID FRANKLIN',
#  'RICHARD CORRIEA',
#  'AMY HART',
#  'SEBASTIAN WONG',
#  'MARTY ROSS',
#  'ELLEN MOFFATT',
#  'VENUS AZAR',
#  'JUDY MELINEK',
#  'GEORGE GARCIA',
#  'VICTOR WYRSCH',
#  'JOSEPH DRISCOLL',
#  'GREGORY SUHR',
#  'JOHN HANLEY',
#  'RAYMOND GUZMAN',
#  'DENISE SCHMITT',
#  'MONICA FIELDS',
#  'HARLAN KELLY-JR',
#  'DAVID SHINN',
#  'GARY AMELIO',
#  'JOHN TURSI',
#  'JOSE VELO',
#  'KHOA TRINH',
#  'SUSAN CURRIN',
#  'JAMES BOSCH',
#  'JONES WONG',
#  'BRENDAN WARD',
#  'MICHAEL THOMPSON',
#  'THOMAS ABBOTT',
#  'THOMAS SIRAGUSA',
#  'MICHAEL THOMPSON',
#  'SHARON MCCOLE WICHER',
#  'EDWIN LEE',
#  'BRYAN RUBENSTEIN',
#  'TRENT RHORER',
# ...

# %%
newlist = ['hi '+i for i in lst]
newlist
# Out:
# ['hi NATHANIEL FORD',
#  'hi GARY JIMENEZ',
#  'hi ALBERT PARDINI',
#  'hi CHRISTOPHER CHONG',
#  'hi PATRICK GARDNER',
#  'hi DAVID SULLIVAN',
#  'hi ALSON LEE',
#  'hi DAVID KUSHNER',
#  'hi MICHAEL MORRIS',
#  'hi JOANNE HAYES-WHITE',
#  'hi ARTHUR KENNEY',
#  'hi PATRICIA JACKSON',
#  'hi EDWARD HARRINGTON',
#  'hi JOHN MARTIN',
#  'hi DAVID FRANKLIN',
#  'hi RICHARD CORRIEA',
#  'hi AMY HART',
#  'hi SEBASTIAN WONG',
#  'hi MARTY ROSS',
#  'hi ELLEN MOFFATT',
#  'hi VENUS AZAR',
#  'hi JUDY MELINEK',
#  'hi GEORGE GARCIA',
#  'hi VICTOR WYRSCH',
#  'hi JOSEPH DRISCOLL',
#  'hi GREGORY SUHR',
#  'hi JOHN HANLEY',
#  'hi RAYMOND GUZMAN',
#  'hi DENISE SCHMITT',
#  'hi MONICA FIELDS',
#  'hi HARLAN KELLY-JR',
#  'hi DAVID SHINN',
#  'hi GARY AMELIO',
#  'hi JOHN TURSI',
#  'hi JOSE VELO',
#  'hi KHOA TRINH',
#  'hi SUSAN CURRIN',
#  'hi JAMES BOSCH',
#  'hi JONES WONG',
#  'hi BRENDAN WARD',
#  'hi MICHAEL THOMPSON',
#  'hi THOMAS ABBOTT',
#  'hi THOMAS SIRAGUSA',
# ...

# %%
newList = [];
for name in lst :
    newList.append('hi '+name)
newList
# Out:
# ['hi NATHANIEL FORD',
#  'hi GARY JIMENEZ',
#  'hi ALBERT PARDINI',
#  'hi CHRISTOPHER CHONG',
#  'hi PATRICK GARDNER',
#  'hi DAVID SULLIVAN',
#  'hi ALSON LEE',
#  'hi DAVID KUSHNER',
#  'hi MICHAEL MORRIS',
#  'hi JOANNE HAYES-WHITE',
#  'hi ARTHUR KENNEY',
#  'hi PATRICIA JACKSON',
#  'hi EDWARD HARRINGTON',
#  'hi JOHN MARTIN',
#  'hi DAVID FRANKLIN',
#  'hi RICHARD CORRIEA',
#  'hi AMY HART',
#  'hi SEBASTIAN WONG',
#  'hi MARTY ROSS',
#  'hi ELLEN MOFFATT',
#  'hi VENUS AZAR',
#  'hi JUDY MELINEK',
#  'hi GEORGE GARCIA',
#  'hi VICTOR WYRSCH',
#  'hi JOSEPH DRISCOLL',
#  'hi GREGORY SUHR',
#  'hi JOHN HANLEY',
#  'hi RAYMOND GUZMAN',
#  'hi DENISE SCHMITT',
#  'hi MONICA FIELDS',
#  'hi HARLAN KELLY-JR',
#  'hi DAVID SHINN',
#  'hi GARY AMELIO',
#  'hi JOHN TURSI',
#  'hi JOSE VELO',
#  'hi KHOA TRINH',
#  'hi SUSAN CURRIN',
#  'hi JAMES BOSCH',
#  'hi JONES WONG',
#  'hi BRENDAN WARD',
#  'hi MICHAEL THOMPSON',
#  'hi THOMAS ABBOTT',
#  'hi THOMAS SIRAGUSA',
# ...
