# %% [markdown]
# تعریف متغیر

# %%
x = 2
y = 3
z=x+y
z
# Out:
# 5

# %% [markdown]
# مقدار دادن به متغیر از یک رابطه و پرینت آن

# %%
z=5 % 2
print(z)
# Out:
# 1

# %% [markdown]
# تعریف رشته و نمایش رشته

# %%
str = 'hello word'
str
print(str[:5])
print(str[5:])
print(str[6])
print(str[6:8])
# Out:
# hello
#  word
# w
# wo

# %% [markdown]
# جایگزاری متغیر در رشته

# %%
x = 2
y = 'five'

print('value x is: {}, and y is: {}'.format(x,y))
# Out:
# value x is: 2, and y is: five

# %% [markdown]
# تعریف لیست ( ارایه)

# %%
list1 = [1,2,3]
print(list1)
list1.append('a')
print(list1)
print(list1[:2])
print(list1[0])
list1[2]=-3
print(list1)
list1[2]='b'
print(list1)
# Out:
# [1, 2, 3]
# [1, 2, 3, 'a']
# [1, 2]
# 1
# [1, 2, -3, 'a']
# [1, 2, 'b', 'a']

# %% [markdown]
# لیست های تو در تو

# %%
list1 = [1, 2, 'b', 'a']
list1.append(['z','y'])
print(list1)
print(list1[4][0])
list2 = list1[4]
print(list2)
# Out:
# [1, 2, 'b', 'a', ['z', 'y']]
# z
# ['z', 'y']
