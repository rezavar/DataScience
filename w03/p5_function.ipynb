# %%
import time

def my_function():
    print("start my_function")
    print(time.time())
    print("end my_function")

my_function()
# Out:
# start my_function
# 1699677915.4775517
# end my_function

# %%
def add_function(a,b,c=100):
    print("start add_function")
    print(a+b+c)
    print("end add_function")

add_function(1,2)
# Out:
# start add_function
# 103
# end add_function

# %%
def ab2_function(a,b):
    return (a+b)*2

x = ab2_function(1,2) 
print(x)
# Out:
# 6
