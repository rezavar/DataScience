# %%
import sys
print(sys.version)
# Out:
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]

# %%
x = str(1.2)
print(x)
x=str(12)
print(x)
print()
print('insert empty line after this print\n')
print('new line')
# Out:
# 1.2
# 12
#
# insert empty line after this print
#
# new line

# %%
print(type(True))

x = 2>1
print(x)
# Out:
# <class 'bool'>
# True

# %%
b = int(True)
print(b)
print(bool(0))
print( float(True) )
# Out:
# 1
# False
# 1.0

# %%
tuple1 = (1,2,3,3,2,1,1,2,4,5,6)
print("tuple 1 is :",m_t)

set1 = set(tuple1)
print("set 1 is: ",set1)

for item in set1:
    print("item "+str(item)+" repeat in tuple : ",m_t.count(item))
# Out:
# tuple 1 is : (1, 2, 3, 3, 2, 1, 1, 2, 4, 5, 6)
# set 1 is:  {1, 2, 3, 4, 5, 6}
# item 1 repeat in tuple :  3
# item 2 repeat in tuple :  3
# item 3 repeat in tuple :  2
# item 4 repeat in tuple :  1
# item 5 repeat in tuple :  1
# item 6 repeat in tuple :  1

# %%
tuple1.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %%
set2 = {1,2,3}
for item in set2:
    if item == 1 :
        print("one")
    elif item == 2 : 
        print("two")
    else:
        print("three")
# Out:
# one
# two
# three

# %%
rang = range(5)
print(rang)
for i in range(5) :
    print(i)
# Out:
# range(0, 5)
# 0
# 1
# 2
# 3
# 4

# %%
result = []
i=1
while i<5:
    result.append(i**2)
    i=i+1
print(result)
# Out:
# [1, 4, 9, 16]

# %%
x = [1,2,3,4]
x = [i**2 for i in x]
print(x)

x = [1,2,3,4]
x = [{"value":i,"result":i>2} for i in x]
print(x)
# Out:
# [1, 4, 9, 16]
# [{'value': 1, 'result': False}, {'value': 2, 'result': False}, {'value': 3, 'result': True}, {'value': 4, 'result': True}]

# %%
v2 = lambda value : value*2
print(v2(3))
# Out:
# 6
