# %%
def print_valueAndType(value):
    print("value = {} type of value is: {}".format(value, type(value)) )


int_sample1 = 5
print_valueAndType(int_sample1)

str_sample2 = '6'
print_valueAndType(str_sample2)

int_from_str_sample3 = int(m2)
print_valueAndType(int_from_str_sample3)

str_start_sample4 = "3"*4
print_valueAndType(str_start_sample4)

str_to_int_sample5 = int("3")+4
print_valueAndType(str_to_int_sample5)

zerro_sample6 = 0
print_valueAndType(zerro_sample6)

float_sample7 = 3.356465
print_valueAndType(float_sample7)

float_to_int_sample7 = int(float_sample7)
print_valueAndType(float_to_int_sample7)
# Out:
# value = 5 type of value is: <class 'int'>
# value = 6 type of value is: <class 'str'>
# value = 6 type of value is: <class 'int'>
# value = 3333 type of value is: <class 'str'>
# value = 7 type of value is: <class 'int'>
# value = 0 type of value is: <class 'int'>
# value = 3.356465 type of value is: <class 'float'>
# value = 3 type of value is: <class 'int'>

# %%
x = 11/2
print(x)

x= 11//2
print(x)
# Out:
# 5.5
# 5

# %%
str = "123456789"
print(str[:4])
print(str[::2])
print(str[2:6])
print(str[2:6:2])
# Out:
# 1234
# 13579
# 3456
# 35
# -9

# %%
str = 'abcdefghij'
print(str[-1])
x= len(str) * -1
print(x)
print(str[x])
# Out:
# j
# -10
# a

# %%
s1 = 'this is'
s2 = 'test'
str = s1+" " +s2
str
# Out:
# 'this is test'
